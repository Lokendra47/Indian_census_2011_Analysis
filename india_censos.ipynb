# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokendra47/Indian_census_2011_Analysis/blob/main/india_censos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library Used in this Project
#
# Project Name- # India census 2011 dataset
#
# Pandas :
# Pandas is an open-source library
# Series
# DataFrame
#
# Matplotlib :
# Used for Visulaization
# Plotting Hraph
#
# Data Set Link: https://www.kaggle.com/datasets/sandragracenelson/indian-populatin-2011

# %% [markdown]
# This data is about population ,Demography, Literracy district states city workers religion education age

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"/India Census 2011.csv")
df
# Out:
#      District_code                   State_name              District_name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %%
# from google.colab import drive
# drive.mount('/content/drive')
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
df.plot.barh()
# Out:
# <Axes: >

# %% [markdown]
# # 1 How will you hide the index in dataframe

# %%
# df.style.hide_index()
# df.head()

###########################################

# # import pandas as pd

# # Check Pandas version
# print(pd.__version__)

# # Upgrade Pandas if necessary
# !pip install --upgrade pandas

##########################################

# Use the correct method to hide the index
df.index.name = None

# Display the DataFrame
df.head()

#########################################

# # Ensure you are importing the correct module
# import pandas as pd

# # Use the correct method to hide the index
# df.index.name = None

# # Display the DataFrame
# df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %% [markdown]
# TO find sex ratio per State

# %% [markdown]
# # Show the total number of population in state wise

# %%
df.groupby('State_name').Population.sum().sort_values(ascending=False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %% [markdown]
# # Total population with diffrent Communities

# %%
df.groupby("State_name")[ ['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains']].sum()
# Out:
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# ANDHRA PRADESH                74824149   8082412     1129784     40244
# ARUNACHAL PRADESH               401876     27045      418732      3287
# ASSAM                         19180759  10679345     1165867     20672
# BIHAR                         86078686  17557809      129247     23779
# CHANDIGARH                      852574     51447        8720    138329
# CHHATTISGARH                  23819789    514998      490542     70036
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# DAMAN AND DIU                   220150     19277        2820       172
# GOA                             963877    121564      366130      1473
# GUJARAT                       53533988   5846761      316178     58246
# HARYANA                       22171128   1781342       50353   1243752
# ...

# %% [markdown]
# # Data based on Community

# %%
df.plot.line(y=['Hindus','Christians','Muslims','Sikhs'	,'Buddhists',	'Jains'],figsize=(20,4),lw=4)
# Out:
# <Axes: >

# %% [markdown]
# # Display the 5 underated State of Hindu Community According to 2011 Census Report

# %%
hindu_community=df.groupby("State_name")[ [ 'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains'] ].sum().sort_values(by=["Hindus"],)
hindu_community.head(5)
# Out:
#                              Hindus  Muslims  Christians  Sikhs  Buddhists  \
# State_name
# LAKSHADWEEP                    1788    62268         317      8         10
# MIZORAM                       30136    14832      956331    286      93411
# NAGALAND                     173054    48963     1739651   1890       6759
# DAMAN AND DIU                220150    19277        2820    172        217
# ANDAMAN AND NICOBAR ISLANDS  264296    32413       80984   1286        338
#
#                              Jains
# State_name
# LAKSHADWEEP                     11
# MIZORAM                        376
# NAGALAND                      2655
# DAMAN AND DIU                  287
# ANDAMAN AND NICOBAR ISLANDS     31

# %% [markdown]
# # top 5 Youth state

# %%
tt=df.groupby("State_name")['Age_Group_0_29'].sum().sort_values()
tt.head(5)
# Out:
# State_name
# LAKSHADWEEP                     33877
# DAMAN AND DIU                  153064
# ANDAMAN AND NICOBAR ISLANDS    204538
# DADRA AND NAGAR HAVELI         225103
# SIKKIM                         364810
# Name: Age_Group_0_29, dtype: int64

# %% [markdown]
# # AGRICULTURE DEPENDICY OF STATE

# %%
df['ag_dependcy']=round((df['Agricultural_Workers']/df['Workers'])*100)

# %%
Agriculture_dependency=df.groupby("State_name")['ag_dependcy']
Agriculture_dependency.first().sort_values(ascending=False)
# Out:
# State_name
# BIHAR                          68.0
# JHARKHAND                      58.0
# MAHARASHTRA                    55.0
# ORISSA                         47.0
# MADHYA PRADESH                 42.0
# ANDHRA PRADESH                 37.0
# KARNATAKA                      31.0
# CHHATTISGARH                   31.0
# UTTAR PRADESH                  26.0
# RAJASTHAN                      25.0
# JAMMU AND KASHMIR              25.0
# GUJARAT                        24.0
# TRIPURA                        22.0
# PONDICHERRY                    20.0
# TAMIL NADU                     18.0
# ASSAM                          17.0
# MEGHALAYA                      16.0
# MANIPUR                        13.0
# PUNJAB                         13.0
# DADRA AND NAGAR HAVELI         11.0
# SIKKIM                         10.0
# WEST BENGAL                    10.0
# KERALA                          8.0
# NAGALAND                        7.0
# HARYANA                         6.0
# ...

# %% [markdown]
# # To find sex ratio

# %%
df['sex_ratio'] = round((df['Female']/df['Male'])*100)

# %% [markdown]
#  # To find literacy

# %%
df['literacy_rate'] = round((df['Literate']/df['Population'])*100)

# %%
df.drop(columns=['Male','Female','Literate','District_name','District_code'],inplace=True)

# %% [markdown]
# Show in table

# %%
df.groupby("State_name")[['literacy_rate','sex_ratio']].sum()
# Out:
#                              literacy_rate  sex_ratio
# State_name
# ANDAMAN AND NICOBAR ISLANDS          224.0      257.0
# ANDHRA PRADESH                      1360.0     2289.0
# ARUNACHAL PRADESH                    870.0     1471.0
# ASSAM                               1669.0     2583.0
# BIHAR                               1917.0     3491.0
# CHANDIGARH                            76.0       82.0
# CHHATTISGARH                        1014.0     1791.0
# DADRA AND NAGAR HAVELI                65.0       77.0
# DAMAN AND DIU                        152.0      156.0
# GOA                                  159.0      195.0
# GUJARAT                             1729.0     2439.0
# HARYANA                             1372.0     1847.0
# HIMACHAL PRADESH                     869.0     1145.0
# JAMMU AND KASHMIR                   1211.0     1943.0
# JHARKHAND                           1296.0     2296.0
# KARNATAKA                           1955.0     2954.0
# ...

# %% [markdown]
# # Sort the values accoroding to Literacy_rate

# %%
rk=df.groupby("State_name")["literacy_rate"]
rk.first().sort_values(ascending=False)
# Out:
# State_name
# LAKSHADWEEP                    82.0
# GOA                            81.0
# TRIPURA                        79.0
# KERALA                         79.0
# CHANDIGARH                     76.0
# TAMIL NADU                     75.0
# NCT OF DELHI                   74.0
# DAMAN AND DIU                  73.0
# HARYANA                        72.0
# PUNJAB                         71.0
# PONDICHERRY                    71.0
# WEST BENGAL                    71.0
# MIZORAM                        70.0
# SIKKIM                         70.0
# ANDAMAN AND NICOBAR ISLANDS    69.0
# ORISSA                         66.0
# UTTARAKHAND                    65.0
# DADRA AND NAGAR HAVELI         65.0
# KARNATAKA                      64.0
# HIMACHAL PRADESH               62.0
# RAJASTHAN                      61.0
# CHHATTISGARH                   60.0
# GUJARAT                        60.0
# UTTAR PRADESH                  60.0
# MEGHALAYA                      56.0
# ...

# %% [markdown]
# # show the litercy_rate in bar plot

# %%
fig = plt.figure(figsize = (30, 10))

# creating the bar plot
plt.bar(df.State_name, df.literacy_rate,)
# Out:
# <BarContainer object of 640 artists>

# %% [markdown]
# # Sort the values accoroding to sex_ratio

# %%
tt=df.groupby("State_name")["sex_ratio"]
tt.first().sort_values(ascending=False)
# Out:
# State_name
# KERALA                         108.0
# PONDICHERRY                    104.0
# DAMAN AND DIU                  103.0
# ANDHRA PRADESH                 100.0
# TAMIL NADU                      99.0
# HIMACHAL PRADESH                99.0
# ORISSA                          98.0
# MEGHALAYA                       98.0
# MAHARASHTRA                     98.0
# WEST BENGAL                     97.0
# CHHATTISGARH                    97.0
# KARNATAKA                       97.0
# UTTARAKHAND                     96.0
# ASSAM                           96.0
# TRIPURA                         96.0
# GOA                             96.0
# LAKSHADWEEP                     95.0
# JHARKHAND                       94.0
# MANIPUR                         94.0
# MIZORAM                         93.0
# BIHAR                           91.0
# GUJARAT                         91.0
# NAGALAND                        90.0
# MADHYA PRADESH                  90.0
# PUNJAB                          90.0
# ...

# %% [markdown]
# # show the sex ratio in bar plot

# %%
fig = plt.figure(figsize = (30, 5))

# creating the bar plot
plt.bar(df.State_name, df.sex_ratio, color ='maroon')
# Out:
# <BarContainer object of 640 artists>

# %% [markdown]
# #  Display the Education based on Standard

# %%
df[['Secondary_Education', 'Higher_Education', 'Graduate_Education']].plot(figsize=(12,5))
# Out:
# <Axes: >

# %% [markdown]
# # How Many workers are Male and Female based on Population

# %%
df.plot.scatter(x='Population',y='Male_Workers',c='Female_Workers',cmap='coolwarm',)
# Out:
# <Axes: xlabel='Population', ylabel='Male_Workers'>

# %%
from google.colab import drive
drive.mount('/content/drive')
